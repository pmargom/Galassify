# %% [markdown]
# # Notebook de Extracción inicial (extraccionInicial.pynb)
# ### Este notebook aglutina todas la acciones realizadas en Python para la extracción inicial de los datos para la creación de un dataset inicial.
#
# La información obtenida viene de dos fuentes principales:
#
# 1- **Base de datos myBestDR7**: Base de datos en SQL Server. Es una pequeña muestra de la base de datos general de SDSS en su versión DR7. Se utiliza esta muestra para obtener las galaxias que serán tratadas.
#
# 2- **Archivos Fits:** Archivos en formato FITS obtenidos de la API de la base de datos SDS. Se accederan a los archivos FITS correspondiente a las galaxias obtenidas de la base de datos myBestDR7.
#
# En este notebook no se entraran en conceptos teóricos. Para ello acceder al notebook "Introducción a ficheros FITS"

# %%
# Preparación
# Llamamos a las librerías que serán necesarias en la ejecución de este notebook
from astropy.io import fits  # Tratamiento de ficheros Fits
import pandas as pd  # Tratamiento de datos como tablas
import os # Librería para gestionar Sisitema Operativo

# Cambiamos la carpeta de trabajo a dónde tenemos los archivos
os.chdir("/home/vicente/Galassify/NoteBooks")

# Configuramos la forma en que se muestran los float (4 decimales)
pd.options.display.float_format = "{:20,.4f}".format

# %% [markdown]
# ## Utilización de la API para acceso a archivos Fits
# Se puede acceder y bajar cualquier archivo fits correspondiente a un espectro determinado, siempre y cuando se tengan las referencias de plate, mjs y fiber.
#
# También se puede acceder al archivo en formato fit o csv, así como una versión reducida o completa.
#
# Para ello utilizaremos la siguiente API:
#
# `https://dr14.sdss.org/optical/spectrum/view/data/format=FORMAT/spec=SPEC?plateid=PLATEID&mjd=MJD&fiberid=FIBERID`<br>
# Ejemplo: Para bajar el siguiente fichero FITS:<br>
# SURVEY : dr14<br>
# FORMAT : fits<br>
# SIZE : little<br>
# PLATEID : 0285<br>
# MJD : 51930<br>
# FIBERID : 0184<br>
# Llamariamos a https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=0285&mjd=51930&fiberid=0184

# %%
# Para facilitar la creación del datset incial, vamos a crear un script que pasado los parametros plate, mjd y fiber
# baje el archivo fit utilizando la API de SDS explicada y devuelve un dataframe con los datos cargados
#Utilizaremos la data release 14

def cargarFit(plate, mjd, fiber):

    url = 'https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=' + str(plate) + '&mjd=' + str(mjd) + '&fiberid=' + str(fiber)
    try:
        hdul = fits.open(url, cache=False)
    except:
        print("**** ERROR bajando archivo ", url)
        return 0
    
    z = hdul[2].data['Z'][0]
    flux = hdul[1].data['FLUX']
    loglam = hdul[1].data['LOGLAM']

    df = pd.DataFrame(columns=['Plate', 'MJD', 'FIBER', 'Z', 'FLUX', 'LOGLAM'])

    # Rellenamos el Dataframe
    for i in range(len(flux)):
        campos = list([plate, mjd, fiber, z, flux[i], loglam[i]])
        registrodf = pd.DataFrame([campos], columns = list(df.columns))
        df = df.append(registrodf, ignore_index=True)

    # Calculamos la columna de longitud de onda en Amstrongs. Recordamos que el valor que se encuentra en el archivo fit es
    # el logaritmo en base 10
    df['LAM'] = 10**df['LOGLAM']

    # Calculamos la corrección del redshift aplicando el factor de corrección Z
    df['LAMZ'] = df['LAM']/(1+df['Z'])
    
    return df

# %% [markdown]
# ## DataSet Base con la relación inicial de Galaxias
# El archivo de entrada dónde se relacionan las galaxias cuyos archivos FIT hay que bajar, se obtiene de realizar la siguientes consulta en la SDSS
#
# SELECT top 3000 Q.plate, Q.mjd, Q.fiberid from
# (
# SELECT TOP 100000 NEWID() as R, s.plate, s.mjd, s.fiberid
# FROM SpecObj AS s
# where (s.z < 0.25) and (s.class = 'GALAXY')
# ) as Q
# Order by Q.R
#
# En esta consulta se obtienen un total de 3000 Galaxias (top 3000) de manera aleatoria (NEWID).
#
# Esta consulta hay que exportarla a un fichero cvs que servirá como fichero de entrada.
# La web dónde se puede realizar la consulta es la siguiente:
# http://skyserver.sdss.org/dr15/en/tools/search/sql.aspx
#
# ## Generación de campos adicionales
# Vamos a proceder a la extracción de los espectros buscados en nuestro Dataset, pero debemos generar campos adicionales que nos permitan realizar la corrección del desaplazamiento al rojo.
#
# Los campos que extreremos de los archivos FITS serán:
# * **Plate:** Plancha desde dónde se realizó la observación del espectro
# * **MJD:** Fecha Juliana de la observación
# * **FIBER:** Fibra desde dónde se realizó la observación del espectro
# * **Z:** Factor Z de corrección del espectro
# * **FLUX:** Valor de luminancia de la observación en la frecuencia dada
# * **LOGLAM** Logaritmo en base 10 de la frecuencia de la ue¡muestra en Amstrongs
#
# Adicionalmente tendremos que calcucar los siguientes campos
# * **LAM:** Frecuencia de la muestra en Amstrong (sin el logaritmo)
# * **LAMZ:** Frecuencia de la muestra en Amstring con la corrección del redshift aplicada (LAMZ = LAM/(1+Z))

# %%
csvEntrada = "muestraGalaxias3KRandom.csv"
csvSalida = "datasetV1_8Campos3K.csv"

# Cargamos el dataset donde tenemos la lista de galaxias en terminos de Plate, MJD y Fiber
dfMuestra = pd.read_csv(csvEntrada, sep=';')

# Comprobamos que no hay ningun NaN en el dataset
dfMuestra.isnull().any()
# Out:
# PLATE    False
# MJD      False
# FIBER    False
# dtype: bool

# %%
# Creamos el dataset que irá contruyendo en el csv de salida.
# ******************** ATENCION Sólo ejecutar si se quiere empezar desde 0 **************************

datasetV1 = pd.DataFrame(columns=['PLATE', 'MJD', 'FIBER', 'Z', 'FLUX', 'LOGLAM', 'LAM', 'LAMZ'])

datasetV1.to_csv(csvSalida, index=False, header=True, sep=';')

# %%
import os

# Calculamos el numero de espectros que ya hay en el csv de Salida para continuar con el proceso.
if (os.path.isfile(csvSalida)):
    # Iteramos sobre el dataset de muestra para ir construyendo el DataSet principal
    csv = pd.read_csv(csvSalida, sep=';')
    ultimaFila = csv[['PLATE', 'MJD', 'FIBER']].drop_duplicates().shape[0]
    
    for i in range(ultimaFila, len(dfMuestra)):
        plate = str(dfMuestra.loc[i, 'PLATE'])
        MJD = str(dfMuestra.loc[i, 'MJD'])
        fiber = str(dfMuestra.loc[i, 'FIBER'])
        df = 0
        while(type(df) == int):
            df = cargarFit(plate, MJD, fiber)
        df.to_csv(csvSalida, mode='a', index=False, header=False, sep=";")
        # datasetV1 = datasetV1.append(df, ignore_index=True)
        print (str(i) + ' (' + str(dfMuestra.loc[i, 'PLATE']) + ', ' + str(dfMuestra.loc[i, 'MJD']) + ', ' + str(dfMuestra.loc[i, 'FIBER']) + ') -> Hecho!')
else:
    print("El archivo " , csvSalida , "no existe")
# Out:
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2099&mjd=53469&fiberid=148 [Done]
# 0 (2099, 53469, 148) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1815&mjd=53884&fiberid=1 [Done]
# 1 (1815, 53884, 1) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=699&mjd=52202&fiberid=92 [Done]
# 2 (699, 52202, 92) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1924&mjd=53330&fiberid=267 [Done]
# 3 (1924, 53330, 267) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5440&mjd=55983&fiberid=132 [Done]
# 4 (5440, 55983, 132) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6035&mjd=56076&fiberid=28 [Done]
# 5 (6035, 56076, 28) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=687&mjd=52518&fiberid=140 [Done]
# 6 (687, 52518, 140) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2595&mjd=54207&fiberid=561 [Done]
# 7 (2595, 54207, 561) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=861&mjd=52318&fiberid=183 [Done]
# 8 (861, 52318, 183) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=512&mjd=51992&fiberid=220 [Done]
# 9 (512, 51992, 220) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2291&mjd=53714&fiberid=166 [Done]
# 10 (2291, 53714, 166) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=449&mjd=51900&fiberid=390 [Done]
# 11 (449, 51900, 390) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2956&mjd=54525&fiberid=616 [Done]
# 12 (2956, 54525, 616) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1972&mjd=53466&fiberid=615 [Done]
# 13 (1972, 53466, 615) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=758&mjd=52253&fiberid=290 [Done]
# 14 (758, 52253, 290) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7841&mjd=56960&fiberid=488 [Done]
# 15 (7841, 56960, 488) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=600&mjd=52317&fiberid=139 [Done]
# 16 (600, 52317, 139) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2238&mjd=54205&fiberid=99 [Done]
# 17 (2238, 54205, 99) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=955&mjd=52409&fiberid=261 [Done]
# 18 (955, 52409, 261) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=826&mjd=52295&fiberid=68 [Done]
# 19 (826, 52295, 68) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1486&mjd=52993&fiberid=57 [Done]
# 20 (1486, 52993, 57) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1357&mjd=53034&fiberid=299 [Done]
# 21 (1357, 53034, 299) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=788&mjd=52338&fiberid=209 [Done]
# 22 (788, 52338, 209) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1288&mjd=52731&fiberid=125 [Done]
# 23 (1288, 52731, 125) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4998&mjd=55722&fiberid=248 [Done]
# 24 (4998, 55722, 248) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=481&mjd=51908&fiberid=114 [Done]
# 25 (481, 51908, 114) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2421&mjd=54153&fiberid=382 [Done]
# 26 (2421, 54153, 382) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=508&mjd=52366&fiberid=356 [Done]
# 27 (508, 52366, 356) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4263&mjd=55484&fiberid=590 [Done]
# 28 (4263, 55484, 590) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=779&mjd=52342&fiberid=63 [Done]
# 29 (779, 52342, 63) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1270&mjd=52991&fiberid=51 [Done]
# 30 (1270, 52991, 51) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=745&mjd=52258&fiberid=118 [Done]
# 31 (745, 52258, 118) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2245&mjd=54208&fiberid=176 [Done]
# 32 (2245, 54208, 176) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2221&mjd=53792&fiberid=6 [Done]
# 33 (2221, 53792, 6) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=942&mjd=52703&fiberid=179 [Done]
# 34 (942, 52703, 179) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2604&mjd=54484&fiberid=456 [Done]
# 35 (2604, 54484, 456) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2509&mjd=54180&fiberid=84 [Done]
# 36 (2509, 54180, 84) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1959&mjd=53440&fiberid=602 [Done]
# 37 (1959, 53440, 602) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4741&mjd=55704&fiberid=16 [Done]
# 38 (4741, 55704, 16) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1365&mjd=53062&fiberid=335 [Done]
# 39 (1365, 53062, 335) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=734&mjd=52224&fiberid=512 [Done]
# 40 (734, 52224, 512) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2238&mjd=54205&fiberid=555 [Done]
# 41 (2238, 54205, 555) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1367&mjd=53083&fiberid=490 [Done]
# 42 (1367, 53083, 490) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1559&mjd=53271&fiberid=292 [Done]
# 43 (1559, 53271, 292) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1371&mjd=52821&fiberid=306 [Done]
# 44 (1371, 52821, 306) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=940&mjd=52670&fiberid=66 [Done]
# 45 (940, 52670, 66) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5866&mjd=56035&fiberid=920 [Done]
# 46 (5866, 56035, 920) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2507&mjd=53876&fiberid=102 [Done]
# 47 (2507, 53876, 102) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1030&mjd=52914&fiberid=606 [Done]
# 48 (1030, 52914, 606) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1165&mjd=52703&fiberid=113 [Done]
# 49 (1165, 52703, 113) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=713&mjd=52178&fiberid=81 [Done]
# 50 (713, 52178, 81) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=450&mjd=51908&fiberid=349 [Done]
# 51 (450, 51908, 349) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1982&mjd=53436&fiberid=44 [Done]
# 52 (1982, 53436, 44) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1948&mjd=53388&fiberid=474 [Done]
# 53 (1948, 53388, 474) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1317&mjd=52765&fiberid=243 [Done]
# 54 (1317, 52765, 243) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2093&mjd=53818&fiberid=315 [Done]
# 55 (2093, 53818, 315) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1404&mjd=52825&fiberid=506 [Done]
# 56 (1404, 52825, 506) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1811&mjd=53533&fiberid=583 [Done]
# 57 (1811, 53533, 583) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1796&mjd=53884&fiberid=137 [Done]
# 58 (1796, 53884, 137) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2218&mjd=53816&fiberid=170 [Done]
# 59 (2218, 53816, 170) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8168&mjd=56992&fiberid=286 [Done]
# 60 (8168, 56992, 286) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=419&mjd=51879&fiberid=550 [Done]
# 61 (419, 51879, 550) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=730&mjd=52466&fiberid=104 [Done]
# 62 (730, 52466, 104) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1462&mjd=53112&fiberid=10 [Done]
# 63 (1462, 53112, 10) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6455&mjd=56370&fiberid=328 [Done]
# 64 (6455, 56370, 328) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4417&mjd=55829&fiberid=778 [Done]
# 65 (4417, 55829, 778) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=739&mjd=52520&fiberid=56 [Done]
# 66 (739, 52520, 56) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1060&mjd=52636&fiberid=8 [Done]
# 67 (1060, 52636, 8) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2355&mjd=53792&fiberid=280 [Done]
# 68 (2355, 53792, 280) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2423&mjd=54149&fiberid=368 [Done]
# 69 (2423, 54149, 368) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2781&mjd=54266&fiberid=286 [Done]
# 70 (2781, 54266, 286) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1439&mjd=53003&fiberid=93 [Done]
# 71 (1439, 53003, 93) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1806&mjd=53559&fiberid=148 [Done]
# 72 (1806, 53559, 148) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=885&mjd=52379&fiberid=502 [Done]
# 73 (885, 52379, 502) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1327&mjd=52781&fiberid=109 [Done]
# 74 (1327, 52781, 109) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2424&mjd=54448&fiberid=359 [Done]
# 75 (2424, 54448, 359) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=275&mjd=51910&fiberid=364 [Done]
# 76 (275, 51910, 364) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=716&mjd=52203&fiberid=136 [Done]
# 77 (716, 52203, 136) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6002&mjd=56104&fiberid=684 [Done]
# 78 (6002, 56104, 684) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7261&mjd=56603&fiberid=196 [Done]
# 79 (7261, 56603, 196) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=813&mjd=52354&fiberid=1 [Done]
# 80 (813, 52354, 1) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1270&mjd=52991&fiberid=608 [Done]
# 81 (1270, 52991, 608) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1368&mjd=53084&fiberid=86 [Done]
# 82 (1368, 53084, 86) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2590&mjd=54175&fiberid=384 [Done]
# 83 (2590, 54175, 384) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=419&mjd=51879&fiberid=408 [Done]
# 84 (419, 51879, 408) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2883&mjd=54525&fiberid=460 [Done]
# 85 (2883, 54525, 460) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2775&mjd=54535&fiberid=128 [Done]
# 86 (2775, 54535, 128) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1272&mjd=52989&fiberid=214 [Done]
# 87 (1272, 52989, 214) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1689&mjd=53177&fiberid=17 [Done]
# 88 (1689, 53177, 17) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2479&mjd=54174&fiberid=541 [Done]
# 89 (2479, 54174, 541) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2425&mjd=54139&fiberid=234 [Done]
# 90 (2425, 54139, 234) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=302&mjd=51688&fiberid=302 [Done]
# 91 (302, 51688, 302) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6714&mjd=56447&fiberid=544 [Done]
# 92 (6714, 56447, 544) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=629&mjd=52051&fiberid=318 [Done]
# 93 (629, 52051, 318) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1359&mjd=53002&fiberid=163 [Done]
# 94 (1359, 53002, 163) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6511&mjd=56540&fiberid=856 [Done]
# 95 (6511, 56540, 856) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1592&mjd=52990&fiberid=288 [Done]
# 96 (1592, 52990, 288) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2644&mjd=54210&fiberid=103 [Done]
# 97 (2644, 54210, 103) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1817&mjd=53851&fiberid=584 [Done]
# 98 (1817, 53851, 584) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1809&mjd=53792&fiberid=228 [Done]
# 99 (1809, 53792, 228) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7282&mjd=56660&fiberid=175 [Done]
# 100 (7282, 56660, 175) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=303&mjd=51615&fiberid=226 [Done]
# 101 (303, 51615, 226) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6682&mjd=56390&fiberid=564 [Done]
# 102 (6682, 56390, 564) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1264&mjd=52707&fiberid=214 [Done]
# 103 (1264, 52707, 214) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=747&mjd=52234&fiberid=214 [Done]
# 104 (747, 52234, 214) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=939&mjd=52636&fiberid=147 [Done]
# 105 (939, 52636, 147) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7050&mjd=56573&fiberid=688 [Done]
# 106 (7050, 56573, 688) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=810&mjd=52672&fiberid=70 [Done]
# 107 (810, 52672, 70) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2345&mjd=53757&fiberid=355 [Done]
# 108 (2345, 53757, 355) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4397&mjd=55921&fiberid=297 [Done]
# 109 (4397, 55921, 297) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5173&mjd=56046&fiberid=26 [Done]
# 110 (5173, 56046, 26) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=513&mjd=51989&fiberid=18 [Done]
# 111 (513, 51989, 18) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4707&mjd=55653&fiberid=78 [Done]
# 112 (4707, 55653, 78) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=665&mjd=52168&fiberid=594 [Done]
# 113 (665, 52168, 594) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1268&mjd=52933&fiberid=482 [Done]
# 114 (1268, 52933, 482) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1820&mjd=54208&fiberid=314 [Done]
# 115 (1820, 54208, 314) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2352&mjd=53770&fiberid=467 [Done]
# 116 (2352, 53770, 467) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2435&mjd=53828&fiberid=281 [Done]
# 117 (2435, 53828, 281) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=408&mjd=51821&fiberid=376 [Done]
# 118 (408, 51821, 376) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1233&mjd=52734&fiberid=272 [Done]
# 119 (1233, 52734, 272) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6203&mjd=56266&fiberid=842 [Done]
# 120 (6203, 56266, 842) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2348&mjd=53757&fiberid=42 [Done]
# 121 (2348, 53757, 42) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1233&mjd=52734&fiberid=43 [Done]
# 122 (1233, 52734, 43) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1387&mjd=53118&fiberid=243 [Done]
# 123 (1387, 53118, 243) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6804&mjd=56447&fiberid=344 [Done]
# 124 (6804, 56447, 344) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1208&mjd=52672&fiberid=92 [Done]
# 125 (1208, 52672, 92) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=532&mjd=51993&fiberid=47 [Done]
# 126 (532, 51993, 47) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=756&mjd=52577&fiberid=566 [Done]
# 127 (756, 52577, 566) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=623&mjd=52051&fiberid=303 [Done]
# 128 (623, 52051, 303) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6285&mjd=56248&fiberid=29 [Done]
# 129 (6285, 56248, 29) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2431&mjd=53818&fiberid=292 [Done]
# 130 (2431, 53818, 292) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=428&mjd=51883&fiberid=80 [Done]
# 131 (428, 51883, 80) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1345&mjd=52814&fiberid=387 [Done]
# 132 (1345, 52814, 387) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5959&mjd=56214&fiberid=840 [Done]
# 133 (5959, 56214, 840) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2485&mjd=54176&fiberid=565 [Done]
# 134 (2485, 54176, 565) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=986&mjd=52443&fiberid=197 [Done]
# 135 (986, 52443, 197) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2434&mjd=53826&fiberid=168 [Done]
# 136 (2434, 53826, 168) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1352&mjd=52819&fiberid=237 [Done]
# 137 (1352, 52819, 237) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=420&mjd=51871&fiberid=466 [Done]
# 138 (420, 51871, 466) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=543&mjd=52017&fiberid=19 [Done]
# 139 (543, 52017, 19) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2601&mjd=54144&fiberid=385 [Done]
# 140 (2601, 54144, 385) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7135&mjd=56564&fiberid=598 [Done]
# 141 (7135, 56564, 598) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2421&mjd=54153&fiberid=429 [Done]
# 142 (2421, 54153, 429) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4730&mjd=55630&fiberid=418 [Done]
# 143 (4730, 55630, 418) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2436&mjd=54054&fiberid=134 [Done]
# 144 (2436, 54054, 134) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=965&mjd=52438&fiberid=75 [Done]
# 145 (965, 52438, 75) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2098&mjd=53460&fiberid=234 [Done]
# 146 (2098, 53460, 234) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2084&mjd=53360&fiberid=22 [Done]
# 147 (2084, 53360, 22) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1557&mjd=53301&fiberid=292 [Done]
# 148 (1557, 53301, 292) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=520&mjd=52288&fiberid=154 [Done]
# 149 (520, 52288, 154) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6796&mjd=56453&fiberid=624 [Done]
# 150 (6796, 56453, 624) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2581&mjd=54085&fiberid=237 [Done]
# 151 (2581, 54085, 237) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2478&mjd=54097&fiberid=62 [Done]
# 152 (2478, 54097, 62) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=740&mjd=52263&fiberid=426 [Done]
# 153 (740, 52263, 426) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=739&mjd=52520&fiberid=240 [Done]
# 154 (739, 52520, 240) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1201&mjd=52674&fiberid=303 [Done]
# 155 (1201, 52674, 303) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4695&mjd=55957&fiberid=438 [Done]
# 156 (4695, 55957, 438) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2595&mjd=54207&fiberid=295 [Done]
# 157 (2595, 54207, 295) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2197&mjd=53555&fiberid=130 [Done]
# 158 (2197, 53555, 130) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=796&mjd=52401&fiberid=122 [Done]
# 159 (796, 52401, 122) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2530&mjd=53881&fiberid=325 [Done]
# 160 (2530, 53881, 325) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=507&mjd=52353&fiberid=72 [Done]
# 161 (507, 52353, 72) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1207&mjd=52672&fiberid=64 [Done]
# 162 (1207, 52672, 64) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=607&mjd=52368&fiberid=470 [Done]
# 163 (607, 52368, 470) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=605&mjd=52353&fiberid=623 [Done]
# 164 (605, 52353, 623) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1007&mjd=52706&fiberid=73 [Done]
# 165 (1007, 52706, 73) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1802&mjd=53885&fiberid=272 [Done]
# 166 (1802, 53885, 272) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2148&mjd=54526&fiberid=182 [Done]
# 167 (2148, 54526, 182) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1232&mjd=52731&fiberid=145 [Done]
# 168 (1232, 52731, 145) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4376&mjd=55863&fiberid=293 [Done]
# 169 (4376, 55863, 293) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2231&mjd=53816&fiberid=14 [Done]
# 170 (2231, 53816, 14) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2761&mjd=54534&fiberid=406 [Done]
# 171 (2761, 54534, 406) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=616&mjd=52442&fiberid=412 [Done]
# 172 (616, 52442, 412) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5955&mjd=56456&fiberid=432 [Done]
# 173 (5955, 56456, 432) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1277&mjd=52765&fiberid=175 [Done]
# 174 (1277, 52765, 175) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1812&mjd=53795&fiberid=492 [Done]
# 175 (1812, 53795, 492) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2240&mjd=53823&fiberid=252 [Done]
# 176 (2240, 53823, 252) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=880&mjd=52367&fiberid=508 [Done]
# 177 (880, 52367, 508) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2515&mjd=54180&fiberid=218 [Done]
# 178 (2515, 54180, 218) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2504&mjd=54179&fiberid=149 [Done]
# 179 (2504, 54179, 149) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5326&mjd=56002&fiberid=494 [Done]
# 180 (5326, 56002, 494) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1995&mjd=53415&fiberid=278 [Done]
# 181 (1995, 53415, 278) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2418&mjd=53794&fiberid=129 [Done]
# 182 (2418, 53794, 129) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4377&mjd=55828&fiberid=922 [Done]
# 183 (4377, 55828, 922) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4497&mjd=55564&fiberid=508 [Done]
# 184 (4497, 55564, 508) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2024&mjd=53503&fiberid=417 [Done]
# 185 (2024, 53503, 417) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1270&mjd=52991&fiberid=447 [Done]
# 186 (1270, 52991, 447) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1381&mjd=53089&fiberid=477 [Done]
# 187 (1381, 53089, 477) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6513&mjd=56543&fiberid=826 [Done]
# 188 (6513, 56543, 826) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1920&mjd=53314&fiberid=565 [Done]
# 189 (1920, 53314, 565) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1165&mjd=52703&fiberid=473 [Done]
# 190 (1165, 52703, 473) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5178&mjd=56246&fiberid=91 [Done]
# 191 (5178, 56246, 91) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=502&mjd=51957&fiberid=263 [Done]
# 192 (502, 51957, 263) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4575&mjd=55590&fiberid=541 [Done]
# 193 (4575, 55590, 541) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=415&mjd=51810&fiberid=87 [Done]
# 194 (415, 51810, 87) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2218&mjd=53816&fiberid=301 [Done]
# 195 (2218, 53816, 301) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2082&mjd=53358&fiberid=633 [Done]
# 196 (2082, 53358, 633) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2431&mjd=53818&fiberid=206 [Done]
# 197 (2431, 53818, 206) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7825&mjd=57030&fiberid=68 [Done]
# 198 (7825, 57030, 68) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1819&mjd=54540&fiberid=485 [Done]
# 199 (1819, 54540, 485) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8430&mjd=57488&fiberid=858 [Done]
# 200 (8430, 57488, 858) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1945&mjd=53387&fiberid=512 [Done]
# 201 (1945, 53387, 512) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2245&mjd=54208&fiberid=508 [Done]
# 202 (2245, 54208, 508) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8829&mjd=57446&fiberid=320 [Done]
# 203 (8829, 57446, 320) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1156&mjd=52641&fiberid=358 [Done]
# 204 (1156, 52641, 358) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1943&mjd=53386&fiberid=170 [Done]
# 205 (1943, 53386, 170) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1357&mjd=53034&fiberid=222 [Done]
# 206 (1357, 53034, 222) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=400&mjd=51820&fiberid=209 [Done]
# 207 (400, 51820, 209) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5796&mjd=56274&fiberid=290 [Done]
# 208 (5796, 56274, 290) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1159&mjd=52669&fiberid=318 [Done]
# 209 (1159, 52669, 318) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7293&mjd=56741&fiberid=905 [Done]
# 210 (7293, 56741, 905) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1941&mjd=53386&fiberid=463 [Done]
# 211 (1941, 53386, 463) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1405&mjd=52826&fiberid=515 [Done]
# 212 (1405, 52826, 515) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=794&mjd=52376&fiberid=392 [Done]
# 213 (794, 52376, 392) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4702&mjd=55618&fiberid=70 [Done]
# 214 (4702, 55618, 70) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1406&mjd=52876&fiberid=499 [Done]
# 215 (1406, 52876, 499) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=506&mjd=52022&fiberid=228 [Done]
# 216 (506, 52022, 228) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1330&mjd=52822&fiberid=192 [Done]
# 217 (1330, 52822, 192) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1371&mjd=52821&fiberid=434 [Done]
# 218 (1371, 52821, 434) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4364&mjd=55855&fiberid=344 [Done]
# 219 (4364, 55855, 344) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=628&mjd=52083&fiberid=356 [Done]
# 220 (628, 52083, 356) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1273&mjd=52993&fiberid=411 [Done]
# 221 (1273, 52993, 411) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=513&mjd=51989&fiberid=399 [Done]
# 222 (513, 51989, 399) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4398&mjd=55946&fiberid=648 [Done]
# 223 (4398, 55946, 648) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=762&mjd=52232&fiberid=246 [Done]
# 224 (762, 52232, 246) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=665&mjd=52168&fiberid=289 [Done]
# 225 (665, 52168, 289) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2599&mjd=54234&fiberid=218 [Done]
# 226 (2599, 54234, 218) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5120&mjd=55895&fiberid=886 [Done]
# 227 (5120, 55895, 886) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=744&mjd=52251&fiberid=400 [Done]
# 228 (744, 52251, 400) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1947&mjd=53431&fiberid=192 [Done]
# 229 (1947, 53431, 192) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=804&mjd=52286&fiberid=98 [Done]
# 230 (804, 52286, 98) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2106&mjd=53714&fiberid=346 [Done]
# 231 (2106, 53714, 346) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=968&mjd=52412&fiberid=185 [Done]
# 232 (968, 52412, 185) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5808&mjd=56325&fiberid=383 [Done]
# 233 (5808, 56325, 383) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=623&mjd=52051&fiberid=300 [Done]
# 234 (623, 52051, 300) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4375&mjd=55889&fiberid=124 [Done]
# 235 (4375, 55889, 124) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1164&mjd=52674&fiberid=233 [Done]
# 236 (1164, 52674, 233) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2600&mjd=54243&fiberid=466 [Done]
# 237 (2600, 54243, 466) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2115&mjd=53535&fiberid=281 [Done]
# 238 (2115, 53535, 281) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1206&mjd=52670&fiberid=129 [Done]
# 239 (1206, 52670, 129) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1970&mjd=53386&fiberid=463 [Done]
# 240 (1970, 53386, 463) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1160&mjd=52674&fiberid=359 [Done]
# 241 (1160, 52674, 359) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2291&mjd=53714&fiberid=254 [Done]
# 242 (2291, 53714, 254) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=425&mjd=51898&fiberid=627 [Done]
# 243 (425, 51898, 627) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1926&mjd=53317&fiberid=325 [Done]
# 244 (1926, 53317, 325) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8831&mjd=57448&fiberid=132 [Done]
# 245 (8831, 57448, 132) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1940&mjd=53383&fiberid=145 [Done]
# 246 (1940, 53383, 145) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1556&mjd=53740&fiberid=208 [Done]
# 247 (1556, 53740, 208) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4305&mjd=55509&fiberid=808 [Done]
# 248 (4305, 55509, 808) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=861&mjd=52318&fiberid=605 [Done]
# 249 (861, 52318, 605) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1450&mjd=53120&fiberid=304 [Done]
# 250 (1450, 53120, 304) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=955&mjd=52409&fiberid=438 [Done]
# 251 (955, 52409, 438) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5982&mjd=56074&fiberid=32 [Done]
# 252 (5982, 56074, 32) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1500&mjd=53730&fiberid=124 [Done]
# 253 (1500, 53730, 124) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4492&mjd=55565&fiberid=716 [Done]
# 254 (4492, 55565, 716) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4356&mjd=55829&fiberid=414 [Done]
# 255 (4356, 55829, 414) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1943&mjd=53386&fiberid=487 [Done]
# 256 (1943, 53386, 487) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=452&mjd=51911&fiberid=361 [Done]
# 257 (452, 51911, 361) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1162&mjd=52668&fiberid=482 [Done]
# 258 (1162, 52668, 482) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2604&mjd=54484&fiberid=158 [Done]
# 259 (2604, 54484, 158) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=777&mjd=52320&fiberid=47 [Done]
# 260 (777, 52320, 47) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6821&mjd=56396&fiberid=625 [Done]
# 261 (6821, 56396, 625) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=447&mjd=51877&fiberid=393 [Done]
# 262 (447, 51877, 393) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2603&mjd=54479&fiberid=636 [Done]
# 263 (2603, 54479, 636) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4178&mjd=55653&fiberid=738 [Done]
# 264 (4178, 55653, 738) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1492&mjd=52932&fiberid=108 [Done]
# 265 (1492, 52932, 108) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1031&mjd=53172&fiberid=457 [Done]
# 266 (1031, 53172, 457) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=560&mjd=52296&fiberid=554 [Done]
# 267 (560, 52296, 554) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=477&mjd=52026&fiberid=259 [Done]
# 268 (477, 52026, 259) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1930&mjd=53347&fiberid=453 [Done]
# 269 (1930, 53347, 453) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=509&mjd=52374&fiberid=609 [Done]
# 270 (509, 52374, 609) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5887&mjd=56035&fiberid=736 [Done]
# 271 (5887, 56035, 736) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4312&mjd=55511&fiberid=928 [Done]
# 272 (4312, 55511, 928) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=473&mjd=51929&fiberid=101 [Done]
# 273 (473, 51929, 101) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5298&mjd=55979&fiberid=964 [Done]
# 274 (5298, 55979, 964) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=506&mjd=52022&fiberid=625 [Done]
# 275 (506, 52022, 625) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2593&mjd=54175&fiberid=317 [Done]
# 276 (2593, 54175, 317) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4569&mjd=55631&fiberid=58 [Done]
# 277 (4569, 55631, 58) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=605&mjd=52353&fiberid=622 [Done]
# 278 (605, 52353, 622) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2433&mjd=53820&fiberid=214 [Done]
# 279 (2433, 53820, 214) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2600&mjd=54243&fiberid=100 [Done]
# 280 (2600, 54243, 100) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1056&mjd=52764&fiberid=194 [Done]
# 281 (1056, 52764, 194) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2246&mjd=53767&fiberid=140 [Done]
# 282 (2246, 53767, 140) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=692&mjd=52201&fiberid=282 [Done]
# 283 (692, 52201, 282) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5856&mjd=56090&fiberid=312 [Done]
# 284 (5856, 56090, 312) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8729&mjd=57399&fiberid=642 [Done]
# 285 (8729, 57399, 642) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2271&mjd=53726&fiberid=389 [Done]
# 286 (2271, 53726, 389) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=732&mjd=52221&fiberid=415 [Done]
# 287 (732, 52221, 415) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1811&mjd=53533&fiberid=438 [Done]
# 288 (1811, 53533, 438) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=559&mjd=52316&fiberid=636 [Done]
# 289 (559, 52316, 636) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=502&mjd=51957&fiberid=151 [Done]
# 290 (502, 51957, 151) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1406&mjd=52876&fiberid=96 [Done]
# 291 (1406, 52876, 96) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1806&mjd=53559&fiberid=632 [Done]
# 292 (1806, 53559, 632) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1405&mjd=52826&fiberid=519 [Done]
# 293 (1405, 52826, 519) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=508&mjd=52366&fiberid=472 [Done]
# 294 (508, 52366, 472) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2159&mjd=54328&fiberid=429 [Done]
# 295 (2159, 54328, 429) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4457&mjd=55858&fiberid=213 [Done]
# 296 (4457, 55858, 213) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2585&mjd=54097&fiberid=483 [Done]
# 297 (2585, 54097, 483) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2440&mjd=53818&fiberid=558 [Done]
# 298 (2440, 53818, 558) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2196&mjd=53534&fiberid=581 [Done]
# 299 (2196, 53534, 581) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2645&mjd=54477&fiberid=300 [Done]
# 300 (2645, 54477, 300) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2423&mjd=54149&fiberid=280 [Done]
# 301 (2423, 54149, 280) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=448&mjd=51900&fiberid=119 [Done]
# 302 (448, 51900, 119) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=791&mjd=52435&fiberid=245 [Done]
# 303 (791, 52435, 245) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1321&mjd=52764&fiberid=156 [Done]
# 304 (1321, 52764, 156) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1276&mjd=53035&fiberid=246 [Done]
# 305 (1276, 53035, 246) -> Hecho!
# ...
# 2898 (513, 51989, 264) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1254&mjd=52972&fiberid=183 [Done]
# 2899 (1254, 52972, 183) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2423&mjd=54149&fiberid=540 [Done]
# 2900 (2423, 54149, 540) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=624&mjd=52377&fiberid=556 [Done]
# 2901 (624, 52377, 556) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=883&mjd=52430&fiberid=509 [Done]
# 2902 (883, 52430, 509) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1320&mjd=52759&fiberid=319 [Done]
# 2903 (1320, 52759, 319) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1263&mjd=52708&fiberid=47 [Done]
# 2904 (1263, 52708, 47) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=860&mjd=52319&fiberid=264 [Done]
# 2905 (860, 52319, 264) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1367&mjd=53083&fiberid=110 [Done]
# 2906 (1367, 53083, 110) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=628&mjd=52083&fiberid=456 [Done]
# 2907 (628, 52083, 456) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=513&mjd=51989&fiberid=427 [Done]
# 2908 (513, 51989, 427) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1375&mjd=53084&fiberid=102 [Done]
# 2909 (1375, 53084, 102) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=528&mjd=52022&fiberid=318 [Done]
# 2910 (528, 52022, 318) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=735&mjd=52519&fiberid=209 [Done]
# 2911 (735, 52519, 209) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7051&mjd=56574&fiberid=853 [Done]
# 2912 (7051, 56574, 853) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=916&mjd=52378&fiberid=420 [Done]
# 2913 (916, 52378, 420) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2598&mjd=54232&fiberid=483 [Done]
# 2914 (2598, 54232, 483) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1927&mjd=53321&fiberid=381 [Done]
# 2915 (1927, 53321, 381) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1423&mjd=53167&fiberid=220 [Done]
# 2916 (1423, 53167, 220) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2657&mjd=54502&fiberid=526 [Done]
# 2917 (2657, 54502, 526) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=395&mjd=51783&fiberid=48 [Done]
# 2918 (395, 51783, 48) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=775&mjd=52295&fiberid=50 [Done]
# 2919 (775, 52295, 50) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2019&mjd=53430&fiberid=152 [Done]
# 2920 (2019, 53430, 152) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=3801&mjd=55509&fiberid=820 [Done]
# 2921 (3801, 55509, 820) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1347&mjd=52823&fiberid=483 [Done]
# 2922 (1347, 52823, 483) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2099&mjd=53469&fiberid=168 [Done]
# 2923 (2099, 53469, 168) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1406&mjd=52876&fiberid=364 [Done]
# 2924 (1406, 52876, 364) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1277&mjd=52765&fiberid=203 [Done]
# 2925 (1277, 52765, 203) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=513&mjd=51989&fiberid=504 [Done]
# 2926 (513, 51989, 504) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=523&mjd=52026&fiberid=100 [Done]
# 2927 (523, 52026, 100) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2097&mjd=53491&fiberid=78 [Done]
# 2928 (2097, 53491, 78) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2106&mjd=53714&fiberid=542 [Done]
# 2929 (2106, 53714, 542) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2107&mjd=53786&fiberid=192 [Done]
# 2930 (2107, 53786, 192) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=512&mjd=51992&fiberid=5 [Done]
# 2931 (512, 51992, 5) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=678&mjd=52884&fiberid=228 [Done]
# 2932 (678, 52884, 228) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=796&mjd=52401&fiberid=58 [Done]
# 2933 (796, 52401, 58) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=483&mjd=51924&fiberid=277 [Done]
# 2934 (483, 51924, 277) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1359&mjd=53002&fiberid=233 [Done]
# 2935 (1359, 53002, 233) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1371&mjd=52821&fiberid=259 [Done]
# 2936 (1371, 52821, 259) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4381&mjd=55824&fiberid=914 [Done]
# 2937 (4381, 55824, 914) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=883&mjd=52430&fiberid=430 [Done]
# 2938 (883, 52430, 430) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6663&mjd=56338&fiberid=659 [Done]
# 2939 (6663, 56338, 659) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6586&mjd=56485&fiberid=478 [Done]
# 2940 (6586, 56485, 478) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=749&mjd=52226&fiberid=593 [Done]
# 2941 (749, 52226, 593) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1933&mjd=53381&fiberid=329 [Done]
# 2942 (1933, 53381, 329) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=268&mjd=51633&fiberid=608 [Done]
# 2943 (268, 51633, 608) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2216&mjd=53795&fiberid=49 [Done]
# 2944 (2216, 53795, 49) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=774&mjd=52286&fiberid=314 [Done]
# 2945 (774, 52286, 314) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=862&mjd=52325&fiberid=375 [Done]
# 2946 (862, 52325, 375) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1365&mjd=53062&fiberid=58 [Done]
# 2947 (1365, 53062, 58) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1213&mjd=52972&fiberid=8 [Done]
# 2948 (1213, 52972, 8) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1577&mjd=53495&fiberid=442 [Done]
# 2949 (1577, 53495, 442) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=560&mjd=52296&fiberid=244 [Done]
# 2950 (560, 52296, 244) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=421&mjd=51821&fiberid=507 [Done]
# 2951 (421, 51821, 507) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=536&mjd=52024&fiberid=62 [Done]
# 2952 (536, 52024, 62) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1371&mjd=52821&fiberid=95 [Done]
# 2953 (1371, 52821, 95) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1055&mjd=52761&fiberid=59 [Done]
# 2954 (1055, 52761, 59) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2342&mjd=53742&fiberid=397 [Done]
# 2955 (2342, 53742, 397) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7912&mjd=57310&fiberid=532 [Done]
# 2956 (7912, 57310, 532) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=540&mjd=51996&fiberid=5 [Done]
# 2957 (540, 51996, 5) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5068&mjd=55749&fiberid=80 [Done]
# 2958 (5068, 55749, 80) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1267&mjd=52932&fiberid=56 [Done]
# 2959 (1267, 52932, 56) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2593&mjd=54175&fiberid=119 [Done]
# 2960 (2593, 54175, 119) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6877&mjd=56544&fiberid=456 [Done]
# 2961 (6877, 56544, 456) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1086&mjd=52525&fiberid=54 [Done]
# 2962 (1086, 52525, 54) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=934&mjd=52672&fiberid=637 [Done]
# 2963 (934, 52672, 637) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=509&mjd=52374&fiberid=35 [Done]
# 2964 (509, 52374, 35) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1577&mjd=53495&fiberid=531 [Done]
# 2965 (1577, 53495, 531) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=501&mjd=52235&fiberid=520 [Done]
# 2966 (501, 52235, 520) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=5895&mjd=56046&fiberid=472 [Done]
# 2967 (5895, 56046, 472) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4659&mjd=55587&fiberid=593 [Done]
# 2968 (4659, 55587, 593) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2150&mjd=54510&fiberid=259 [Done]
# 2969 (2150, 54510, 259) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6274&mjd=56550&fiberid=1000 [Done]
# 2970 (6274, 56550, 1000) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4541&mjd=55882&fiberid=87 [Done]
# 2971 (4541, 55882, 87) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2495&mjd=54175&fiberid=204 [Done]
# 2972 (2495, 54175, 204) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1419&mjd=53144&fiberid=124 [Done]
# 2973 (1419, 53144, 124) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=430&mjd=51877&fiberid=252 [Done]
# 2974 (430, 51877, 252) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=758&mjd=52253&fiberid=284 [Done]
# 2975 (758, 52253, 284) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2297&mjd=53738&fiberid=292 [Done]
# 2976 (2297, 53738, 292) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2243&mjd=53794&fiberid=94 [Done]
# 2977 (2243, 53794, 94) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1361&mjd=53047&fiberid=160 [Done]
# 2978 (1361, 53047, 160) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2345&mjd=53757&fiberid=490 [Done]
# 2979 (2345, 53757, 490) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1368&mjd=53084&fiberid=124 [Done]
# 2980 (1368, 53084, 124) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=603&mjd=52056&fiberid=500 [Done]
# 2981 (603, 52056, 500) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4421&mjd=55858&fiberid=360 [Done]
# 2982 (4421, 55858, 360) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1508&mjd=52944&fiberid=324 [Done]
# 2983 (1508, 52944, 324) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1789&mjd=54259&fiberid=277 [Done]
# 2984 (1789, 54259, 277) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1984&mjd=53433&fiberid=482 [Done]
# 2985 (1984, 53433, 482) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=4605&mjd=55971&fiberid=789 [Done]
# 2986 (4605, 55971, 789) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1334&mjd=52764&fiberid=413 [Done]
# 2987 (1334, 52764, 413) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2100&mjd=53713&fiberid=117 [Done]
# 2988 (2100, 53713, 117) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=528&mjd=52022&fiberid=186 [Done]
# 2989 (528, 52022, 186) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=8366&mjd=57432&fiberid=164 [Done]
# 2990 (8366, 57432, 164) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=6142&mjd=56219&fiberid=159 [Done]
# 2991 (6142, 56219, 159) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7388&mjd=56783&fiberid=486 [Done]
# 2992 (7388, 56783, 486) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1383&mjd=53116&fiberid=235 [Done]
# 2993 (1383, 53116, 235) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=543&mjd=52017&fiberid=40 [Done]
# 2994 (543, 52017, 40) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=794&mjd=52376&fiberid=590 [Done]
# 2995 (794, 52376, 590) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=7892&mjd=57333&fiberid=993 [Done]
# 2996 (7892, 57333, 993) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2418&mjd=53794&fiberid=137 [Done]
# 2997 (2418, 53794, 137) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=1202&mjd=52672&fiberid=616 [Done]
# 2998 (1202, 52672, 616) -> Hecho!
# Downloading https://dr14.sdss.org/optical/spectrum/view/data/format=fits/spec=lite?plateid=2219&mjd=53816&fiberid=36 [Done]
# 2999 (2219, 53816, 36) -> Hecho!
